# %%
from pyspark.sql.functions import col, length, upper, rand, expr

# %%
spark.sql("""
    CREATE TABLE IF NOT EXISTS local.db.sales_data (
        id INT,
        region STRING,
        product STRING,
        amount DOUBLE,
        sales_date DATE
    )
    USING iceberg
    PARTITIONED BY (region)
""")
# Out:
# DataFrame[]

# %%
# Insert sample data
spark.sql("""
    INSERT INTO local.db.sales_data VALUES
    (1, 'North', 'Widget', 100.0, DATE('2024-01-01')),
    (2, 'South', 'Widget', 200.0, DATE('2024-01-02')),
    (3, 'East',  'Gadget', 150.0, DATE('2024-02-01')),
    (4, 'West',  'Gadget', 300.0, DATE('2024-03-01')),
    (5, 'North', 'Gizmo',  250.0, DATE('2024-03-15'))
""")
# Out:
# DataFrame[]

# %%
# Run filter query with region = 'North'
print("Filtered Data (region = 'North'):")
df_filtered = spark.read.format("iceberg").load("local.db.sales_data").filter(col("region") == "North")
df_filtered.show()
# Out:
# Filtered Data (region = 'North'):
# +---+------+-------+------+----------+
# | id|region|product|amount|sales_date|
# +---+------+-------+------+----------+
# |  1| North| Widget| 100.0|2024-01-01|
# |  5| North|  Gizmo| 250.0|2024-03-15|
# +---+------+-------+------+----------+

# %%
# View the query execution plan to see filter pushdown
print("Query Execution Plan:")
df_filtered.explain(extended=True)
# Out:
# Query Execution Plan:
# == Parsed Logical Plan ==
# 'Filter ('region = North)
# +- RelationV2[id#540, region#541, product#542, amount#543, sales_date#544] local.db.sales_data local.db.sales_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, sales_date: date
# Filter (region#541 = North)
# +- RelationV2[id#540, region#541, product#542, amount#543, sales_date#544] local.db.sales_data local.db.sales_data
#
# == Optimized Logical Plan ==
# RelationV2[id#540, region#541, product#542, amount#543, sales_date#544] local.db.sales_data
#
# == Physical Plan ==
# *(1) ColumnarToRow
# +- BatchScan local.db.sales_data[id#540, region#541, product#542, amount#543, sales_date#544] local.db.sales_data (branch=null) [filters=region IS NOT NULL, region = 'North', groupedBy=] RuntimeFilters: []

# %%
from pyspark.sql.functions import length

# Filter on a derived column (not eligible for pushdown)
df_derived = spark.read.format("iceberg").load("local.db.sales_data") \
    .filter(length(col("region")) > 5)

# Show results
print("Filtered Data (length(region) > 5):")
df_derived.show()

# Show the query execution plan
print("Execution Plan for Non-Pushdown Filter:")
df_derived.explain(extended=True)
# Out:
# Filtered Data (length(region) > 5):
# +---+------+-------+------+----------+
# | id|region|product|amount|sales_date|
# +---+------+-------+------+----------+
# +---+------+-------+------+----------+
#
# Execution Plan for Non-Pushdown Filter:
# == Parsed Logical Plan ==
# 'Filter (length('region) > 5)
# +- RelationV2[id#586, region#587, product#588, amount#589, sales_date#590] local.db.sales_data local.db.sales_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, sales_date: date
# Filter (length(region#587) > 5)
# +- RelationV2[id#586, region#587, product#588, amount#589, sales_date#590] local.db.sales_data local.db.sales_data
#
# == Optimized Logical Plan ==
# Filter (length(region#587) > 5)
# +- RelationV2[id#586, region#587, product#588, amount#589, sales_date#590] local.db.sales_data
#
# == Physical Plan ==
# *(1) Filter (length(region#587) > 5)
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.sales_data[id#586, region#587, product#588, amount#589, sales_date#590] local.db.sales_data (branch=null) [filters=region IS NOT NULL, groupedBy=] RuntimeFilters: []

# %%
# Create test table
spark.sql("""
    CREATE TABLE IF NOT EXISTS local.db.filter_test_data (
        id INT,
        region STRING,
        product STRING,
        amount DOUBLE,
        city STRING
    )
    USING iceberg
""")

# Insert sample data
spark.sql("""
    INSERT INTO local.db.filter_test_data VALUES
    (1, 'North', 'Widget', 120.0, 'Paris'),
    (2, 'South', 'Gadget', 80.0, 'London'),
    (3, 'West', 'Gizmo', 200.0, NULL),
    (4, 'East', 'Widget', 300.0, 'Berlin'),
    (5, NULL, 'Gadget', 50.0, 'Paris')
""")

# List of filter scenarios (description, DataFrame with filter)
scenarios = [
    ("1. Simple filter (pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter(col("region") == "North")),
    ("2. Derived expression (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter(length(col("region")) > 5)),
    ("3. Arithmetic expression (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter(col("amount") + 10 > 100)),
    ("4. Function on column (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter(upper(col("product")) == "WIDGET")),
    ("5. Non-deterministic function (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter(rand() > 0.5)),
    ("6. Compound NULL logic (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter((col("region").isNull()) | (col("region") == "North"))),
    ("7. CASE WHEN expression (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter(expr("CASE WHEN amount > 100 THEN 1 ELSE 0 END = 1"))),
    ("8. Constant on left (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter(expr("'North' = region"))),
    ("9. OR expression (no pushdown)", spark.read.format("iceberg").load("local.db.filter_test_data").filter((col("region") == "North") | (length(col("region")) > 5))),
]

# Evaluate and show plans
for desc, df in scenarios:
    print(f"\n--- {desc} ---")
    df.show()
    df.explain(extended=True)
# Out:
# --- 1. Simple filter (pushdown) ---
# +---+------+-------+------+-----+
# | id|region|product|amount| city|
# +---+------+-------+------+-----+
# |  1| North| Widget| 120.0|Paris|
# +---+------+-------+------+-----+
#
# == Parsed Logical Plan ==
# 'Filter ('region = North)
# +- RelationV2[id#984, region#985, product#986, amount#987, city#988] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter (region#985 = North)
# +- RelationV2[id#984, region#985, product#986, amount#987, city#988] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter (isnotnull(region#985) AND (region#985 = North))
# +- RelationV2[id#984, region#985, product#986, amount#987, city#988] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter (isnotnull(region#985) AND (region#985 = North))
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#984, region#985, product#986, amount#987, city#988] local.db.filter_test_data (branch=null) [filters=region IS NOT NULL, region = 'North', groupedBy=] RuntimeFilters: []
#
#
# --- 2. Derived expression (no pushdown) ---
# +---+------+-------+------+----+
# | id|region|product|amount|city|
# +---+------+-------+------+----+
# +---+------+-------+------+----+
#
# == Parsed Logical Plan ==
# 'Filter (length('region) > 5)
# +- RelationV2[id#999, region#1000, product#1001, amount#1002, city#1003] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter (length(region#1000) > 5)
# +- RelationV2[id#999, region#1000, product#1001, amount#1002, city#1003] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter (isnotnull(region#1000) AND (length(region#1000) > 5))
# +- RelationV2[id#999, region#1000, product#1001, amount#1002, city#1003] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter (isnotnull(region#1000) AND (length(region#1000) > 5))
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#999, region#1000, product#1001, amount#1002, city#1003] local.db.filter_test_data (branch=null) [filters=region IS NOT NULL, groupedBy=] RuntimeFilters: []
#
#
# --- 3. Arithmetic expression (no pushdown) ---
# +---+------+-------+------+------+
# | id|region|product|amount|  city|
# +---+------+-------+------+------+
# |  1| North| Widget| 120.0| Paris|
# |  3|  West|  Gizmo| 200.0|  NULL|
# |  4|  East| Widget| 300.0|Berlin|
# +---+------+-------+------+------+
#
# == Parsed Logical Plan ==
# 'Filter (('amount + 10) > 100)
# +- RelationV2[id#1014, region#1015, product#1016, amount#1017, city#1018] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter ((amount#1017 + cast(10 as double)) > cast(100 as double))
# +- RelationV2[id#1014, region#1015, product#1016, amount#1017, city#1018] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter (isnotnull(amount#1017) AND ((amount#1017 + 10.0) > 100.0))
# +- RelationV2[id#1014, region#1015, product#1016, amount#1017, city#1018] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter (isnotnull(amount#1017) AND ((amount#1017 + 10.0) > 100.0))
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#1014, region#1015, product#1016, amount#1017, city#1018] local.db.filter_test_data (branch=null) [filters=amount IS NOT NULL, groupedBy=] RuntimeFilters: []
#
#
# --- 4. Function on column (no pushdown) ---
# +---+------+-------+------+------+
# | id|region|product|amount|  city|
# +---+------+-------+------+------+
# |  1| North| Widget| 120.0| Paris|
# |  4|  East| Widget| 300.0|Berlin|
# +---+------+-------+------+------+
#
# == Parsed Logical Plan ==
# 'Filter (upper('product) = WIDGET)
# +- RelationV2[id#1029, region#1030, product#1031, amount#1032, city#1033] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter (upper(product#1031) = WIDGET)
# +- RelationV2[id#1029, region#1030, product#1031, amount#1032, city#1033] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter (isnotnull(product#1031) AND (upper(product#1031) = WIDGET))
# +- RelationV2[id#1029, region#1030, product#1031, amount#1032, city#1033] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter (isnotnull(product#1031) AND (upper(product#1031) = WIDGET))
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#1029, region#1030, product#1031, amount#1032, city#1033] local.db.filter_test_data (branch=null) [filters=product IS NOT NULL, groupedBy=] RuntimeFilters: []
#
#
# --- 5. Non-deterministic function (no pushdown) ---
# +---+------+-------+------+------+
# | id|region|product|amount|  city|
# +---+------+-------+------+------+
# |  4|  East| Widget| 300.0|Berlin|
# +---+------+-------+------+------+
#
# == Parsed Logical Plan ==
# Filter (rand(8638275537651420504) > 0.5)
# +- RelationV2[id#1044, region#1045, product#1046, amount#1047, city#1048] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter (rand(8638275537651420504) > 0.5)
# +- RelationV2[id#1044, region#1045, product#1046, amount#1047, city#1048] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter (rand(8638275537651420504) > 0.5)
# +- RelationV2[id#1044, region#1045, product#1046, amount#1047, city#1048] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter (rand(8638275537651420504) > 0.5)
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#1044, region#1045, product#1046, amount#1047, city#1048] local.db.filter_test_data (branch=null) [filters=, groupedBy=] RuntimeFilters: []
#
#
# --- 6. Compound NULL logic (no pushdown) ---
# +---+------+-------+------+-----+
# | id|region|product|amount| city|
# +---+------+-------+------+-----+
# |  1| North| Widget| 120.0|Paris|
# |  5|  NULL| Gadget|  50.0|Paris|
# +---+------+-------+------+-----+
#
# == Parsed Logical Plan ==
# 'Filter (isnull('region) OR ('region = North))
# +- RelationV2[id#1054, region#1055, product#1056, amount#1057, city#1058] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter (isnull(region#1055) OR (region#1055 = North))
# +- RelationV2[id#1054, region#1055, product#1056, amount#1057, city#1058] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter (isnull(region#1055) OR (region#1055 = North))
# +- RelationV2[id#1054, region#1055, product#1056, amount#1057, city#1058] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter (isnull(region#1055) OR (region#1055 = North))
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#1054, region#1055, product#1056, amount#1057, city#1058] local.db.filter_test_data (branch=null) [filters=(region IS NULL OR region = 'North'), groupedBy=] RuntimeFilters: []
#
#
# --- 7. CASE WHEN expression (no pushdown) ---
# +---+------+-------+------+------+
# | id|region|product|amount|  city|
# +---+------+-------+------+------+
# |  1| North| Widget| 120.0| Paris|
# |  3|  West|  Gizmo| 200.0|  NULL|
# |  4|  East| Widget| 300.0|Berlin|
# +---+------+-------+------+------+
#
# == Parsed Logical Plan ==
# 'Filter (CASE WHEN ('amount > 100) THEN 1 ELSE 0 END = 1)
# +- RelationV2[id#1069, region#1070, product#1071, amount#1072, city#1073] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter (CASE WHEN (amount#1072 > cast(100 as double)) THEN 1 ELSE 0 END = 1)
# +- RelationV2[id#1069, region#1070, product#1071, amount#1072, city#1073] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter ((amount#1072 > 100.0) <=> true)
# +- RelationV2[id#1069, region#1070, product#1071, amount#1072, city#1073] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter ((amount#1072 > 100.0) <=> true)
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#1069, region#1070, product#1071, amount#1072, city#1073] local.db.filter_test_data (branch=null) [filters=, groupedBy=] RuntimeFilters: []
#
#
# --- 8. Constant on left (no pushdown) ---
# +---+------+-------+------+-----+
# | id|region|product|amount| city|
# +---+------+-------+------+-----+
# |  1| North| Widget| 120.0|Paris|
# +---+------+-------+------+-----+
#
# == Parsed Logical Plan ==
# 'Filter (North = 'region)
# +- RelationV2[id#1084, region#1085, product#1086, amount#1087, city#1088] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter (North = region#1085)
# +- RelationV2[id#1084, region#1085, product#1086, amount#1087, city#1088] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter (isnotnull(region#1085) AND (North = region#1085))
# +- RelationV2[id#1084, region#1085, product#1086, amount#1087, city#1088] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter (isnotnull(region#1085) AND (North = region#1085))
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#1084, region#1085, product#1086, amount#1087, city#1088] local.db.filter_test_data (branch=null) [filters=region IS NOT NULL, region = 'North', groupedBy=] RuntimeFilters: []
#
#
# --- 9. OR expression (no pushdown) ---
# +---+------+-------+------+-----+
# | id|region|product|amount| city|
# +---+------+-------+------+-----+
# |  1| North| Widget| 120.0|Paris|
# +---+------+-------+------+-----+
#
# == Parsed Logical Plan ==
# 'Filter (('region = North) OR (length('region) > 5))
# +- RelationV2[id#1099, region#1100, product#1101, amount#1102, city#1103] local.db.filter_test_data local.db.filter_test_data
#
# == Analyzed Logical Plan ==
# id: int, region: string, product: string, amount: double, city: string
# Filter ((region#1100 = North) OR (length(region#1100) > 5))
# +- RelationV2[id#1099, region#1100, product#1101, amount#1102, city#1103] local.db.filter_test_data local.db.filter_test_data
#
# == Optimized Logical Plan ==
# Filter ((region#1100 = North) OR (length(region#1100) > 5))
# +- RelationV2[id#1099, region#1100, product#1101, amount#1102, city#1103] local.db.filter_test_data
#
# == Physical Plan ==
# *(1) Filter ((region#1100 = North) OR (length(region#1100) > 5))
# +- *(1) ColumnarToRow
#    +- BatchScan local.db.filter_test_data[id#1099, region#1100, product#1101, amount#1102, city#1103] local.db.filter_test_data (branch=null) [filters=, groupedBy=] RuntimeFilters: []
